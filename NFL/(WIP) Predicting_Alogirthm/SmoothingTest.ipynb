# %%
import cv2
import base64
import requests
import time
from collections import deque
import numpy as np

# Settings
VIDEO_PATH = "Test1.mp4"
OUTPUT_PATH = "smoothed_tracking.mp4"
API_URL = "https://detect.roboflow.com/nfl-object-tracking/4?api_key=RsIHVYfJftsspBQBQPkK&confidence=0.2"
MAX_HISTORY = 5  # Number of past positions to average

# Load video
cap = cv2.VideoCapture(VIDEO_PATH)
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(OUTPUT_PATH, fourcc, 20.0, (int(cap.get(3)), int(cap.get(4))))

# For smoothing
position_history = deque(maxlen=MAX_HISTORY)

frame_num = 0

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Encode frame
    _, buffer = cv2.imencode('.jpg', frame)
    b64 = base64.b64encode(buffer).decode('utf-8')

    # Roboflow detection
    response = requests.post(API_URL, data=b64, headers={"Content-Type": "application/x-www-form-urlencoded"})
    try:
        json_data = response.json()
        predictions = json_data.get("predictions", [])
        print(f"Frame {frame_num} Predictions: {predictions}")
    except Exception as e:
        print(f"❌ Error parsing JSON at frame {frame_num}: {e}")
        predictions = []


    ball_detected = False
    for pred in predictions:
        if pred["class"] == "Ball" and float(pred["confidence"]) > 0.1:
            print("Detected:", pred["class"], "Confidence:", pred["confidence"])
            x, y = int(pred["x"]), int(pred["y"])
            position_history.append((x, y))
            ball_detected = True
            break  # Use only first confident ball detection

    # Smooth using average of last N positions
    if position_history:
        xs, ys = zip(*position_history)
        avg_x = int(np.mean(xs))
        avg_y = int(np.mean(ys))

        # Draw smoothed position
        cv2.circle(frame, (avg_x, avg_y), 12, (0, 255, 255), -1)
        cv2.putText(frame, "Smoothed Ball", (avg_x + 10, avg_y),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 2)

    # Save frame
    out.write(frame)
    print(f"Processed frame {frame_num}")
    frame_num += 1
    time.sleep(0.1)

# Cleanup
cap.release()
out.release()
print(f"✅ Video saved: {OUTPUT_PATH}")
# Out:
# Frame 0 Predictions: []
# Processed frame 0
# Frame 1 Predictions: []
# Processed frame 1
# Frame 2 Predictions: []
# Processed frame 2
# Frame 3 Predictions: []
# Processed frame 3
# Frame 4 Predictions: []
# Processed frame 4
# Frame 5 Predictions: []
# Processed frame 5
# Frame 6 Predictions: []
# Processed frame 6
# Frame 7 Predictions: []
# Processed frame 7
# Frame 8 Predictions: []
# Processed frame 8
# Frame 9 Predictions: []
# Processed frame 9
# Frame 10 Predictions: []
# Processed frame 10
# Frame 11 Predictions: []
# Processed frame 11
# Frame 12 Predictions: []
# Processed frame 12
# Frame 13 Predictions: [{'x': 402.5, 'y': 488.5, 'width': 21.0, 'height': 21.0, 'confidence': 0.44068291783332825, 'class': 'Ball', 'class_id': 0, 'detection_id': 'b8b8992f-40d2-4a27-a28b-53b8cbd2ee6f'}]
# Detected: Ball Confidence: 0.44068291783332825
# Processed frame 13
# Frame 14 Predictions: [{'x': 401.0, 'y': 489.0, 'width': 22.0, 'height': 20.0, 'confidence': 0.27725210785865784, 'class': 'Ball', 'class_id': 0, 'detection_id': '4f79963f-165f-4c5f-813b-416e21f34cf3'}]
# Detected: Ball Confidence: 0.27725210785865784
# Processed frame 14
# Frame 15 Predictions: []
# Processed frame 15
# Frame 16 Predictions: []
# Processed frame 16
# Frame 17 Predictions: []
# Processed frame 17
# Frame 18 Predictions: [{'x': 1328.0, 'y': 497.5, 'width': 20.0, 'height': 17.0, 'confidence': 0.36808308959007263, 'class': 'Ball', 'class_id': 0, 'detection_id': '5d1112dd-3c44-4646-a276-350a911144df'}]
# Detected: Ball Confidence: 0.36808308959007263
# Processed frame 18
# Frame 19 Predictions: [{'x': 398.0, 'y': 490.0, 'width': 24.0, 'height': 24.0, 'confidence': 0.5259207487106323, 'class': 'Ball', 'class_id': 0, 'detection_id': '11487d66-84f1-4d8a-a8a1-4bc0c2f7cad2'}]
# Detected: Ball Confidence: 0.5259207487106323
# Processed frame 19
# Frame 20 Predictions: [{'x': 395.0, 'y': 494.5, 'width': 26.0, 'height': 23.0, 'confidence': 0.4132081866264343, 'class': 'Ball', 'class_id': 0, 'detection_id': '4fb70b6f-ba4c-45f7-b93a-5892785ca7ac'}]
# Detected: Ball Confidence: 0.4132081866264343
# Processed frame 20
# Frame 21 Predictions: [{'x': 393.0, 'y': 500.0, 'width': 24.0, 'height': 20.0, 'confidence': 0.3186368942260742, 'class': 'Ball', 'class_id': 0, 'detection_id': '5182863c-8c43-44ad-804f-59a076ad5efa'}]
# Detected: Ball Confidence: 0.3186368942260742
# Processed frame 21
# Frame 22 Predictions: [{'x': 388.0, 'y': 502.0, 'width': 24.0, 'height': 24.0, 'confidence': 0.4900032579898834, 'class': 'Ball', 'class_id': 0, 'detection_id': '0babd689-c38e-464f-879a-fa64e6822d7e'}]
# Detected: Ball Confidence: 0.4900032579898834
# Processed frame 22
# Frame 23 Predictions: [{'x': 389.0, 'y': 510.0, 'width': 24.0, 'height': 22.0, 'confidence': 0.2970515489578247, 'class': 'Ball', 'class_id': 0, 'detection_id': '401e1a9b-01bf-4250-977a-94e0c8fa435a'}]
# Detected: Ball Confidence: 0.2970515489578247
# Processed frame 23
# Frame 24 Predictions: [{'x': 387.0, 'y': 516.0, 'width': 22.0, 'height': 22.0, 'confidence': 0.353751003742218, 'class': 'Ball', 'class_id': 0, 'detection_id': 'a0a90e0a-21cf-41ed-a0f1-28c25cbe7e2b'}]
# Detected: Ball Confidence: 0.353751003742218
# Processed frame 24
# Frame 25 Predictions: []
# Processed frame 25
# Frame 26 Predictions: []
# Processed frame 26
# Frame 27 Predictions: []
# Processed frame 27
# Frame 28 Predictions: []
# Processed frame 28
# Frame 29 Predictions: []
# Processed frame 29
# Frame 30 Predictions: []
# Processed frame 30
# Frame 31 Predictions: [{'x': 979.5, 'y': 559.5, 'width': 17.0, 'height': 17.0, 'confidence': 0.28309425711631775, 'class': 'Ball', 'class_id': 0, 'detection_id': 'df49630e-63e9-4dd1-a18e-7f04921ccd35'}]
# Detected: Ball Confidence: 0.28309425711631775
# Processed frame 31
# Frame 32 Predictions: [{'x': 1712.0, 'y': 491.5, 'width': 14.0, 'height': 19.0, 'confidence': 0.29389968514442444, 'class': 'Ball', 'class_id': 0, 'detection_id': '431afa8f-8d04-4bc7-900d-2157dbfb1777'}]
# Detected: Ball Confidence: 0.29389968514442444
# Processed frame 32
# Frame 33 Predictions: []
# Processed frame 33
# Frame 34 Predictions: []
# Processed frame 34
# Frame 35 Predictions: []
# Processed frame 35
# Frame 36 Predictions: []
# Processed frame 36
# Frame 37 Predictions: []
# Processed frame 37
# Frame 38 Predictions: []
# Processed frame 38
# Frame 39 Predictions: []
# Processed frame 39
# Frame 40 Predictions: [{'x': 360.0, 'y': 519.5, 'width': 30.0, 'height': 19.0, 'confidence': 0.45462241768836975, 'class': 'Ball', 'class_id': 0, 'detection_id': '37d0f618-155d-485f-89b8-9004c4d505b6'}]
# Detected: Ball Confidence: 0.45462241768836975
# Processed frame 40
# Frame 41 Predictions: [{'x': 362.0, 'y': 508.5, 'width': 28.0, 'height': 19.0, 'confidence': 0.5046607255935669, 'class': 'Ball', 'class_id': 0, 'detection_id': '0e39f63f-d75e-485b-b874-87275ee0cc72'}]
# Detected: Ball Confidence: 0.5046607255935669
# Processed frame 41
# Frame 42 Predictions: []
# Processed frame 42
# Frame 43 Predictions: []
# Processed frame 43
# Frame 44 Predictions: [{'x': 380.0, 'y': 485.5, 'width': 24.0, 'height': 19.0, 'confidence': 0.608752965927124, 'class': 'Ball', 'class_id': 0, 'detection_id': '245e799e-9946-4998-87d9-b42bb9987ed4'}, {'x': 447.5, 'y': 541.5, 'width': 21.0, 'height': 29.0, 'confidence': 0.3631686568260193, 'class': 'Ball', 'class_id': 0, 'detection_id': '5ff00081-4b77-4351-8881-7e0193c8a4bd'}]
# Detected: Ball Confidence: 0.608752965927124
# Processed frame 44
# Frame 45 Predictions: [{'x': 435.5, 'y': 472.5, 'width': 31.0, 'height': 21.0, 'confidence': 0.6001498699188232, 'class': 'Ball', 'class_id': 0, 'detection_id': 'e6ca511d-1257-457d-aefb-73465d40307f'}, {'x': 437.0, 'y': 552.0, 'width': 22.0, 'height': 26.0, 'confidence': 0.2013702243566513, 'class': 'Ball', 'class_id': 0, 'detection_id': 'c29a3553-9758-4cc0-a5bb-ab71bc2cf57b'}]
# Detected: Ball Confidence: 0.6001498699188232
# Processed frame 45
# Frame 46 Predictions: [{'x': 490.0, 'y': 469.5, 'width': 30.0, 'height': 21.0, 'confidence': 0.6166905760765076, 'class': 'Ball', 'class_id': 0, 'detection_id': '4f501f09-e9d3-4ea0-8b68-78f6762ce9e6'}]
# Detected: Ball Confidence: 0.6166905760765076
# Processed frame 46
# Frame 47 Predictions: []
# Processed frame 47
# Frame 48 Predictions: []
# Processed frame 48
# Frame 49 Predictions: []
# Processed frame 49
# Frame 50 Predictions: []
# Processed frame 50
# Frame 51 Predictions: [{'x': 721.0, 'y': 422.0, 'width': 28.0, 'height': 22.0, 'confidence': 0.39107203483581543, 'class': 'Ball', 'class_id': 0, 'detection_id': '89bf76a0-5c1c-4146-bf1a-151b7379ba3b'}]
# Detected: Ball Confidence: 0.39107203483581543
# Processed frame 51
# Frame 52 Predictions: []
# Processed frame 52
# Frame 53 Predictions: [{'x': 791.5, 'y': 410.5, 'width': 27.0, 'height': 19.0, 'confidence': 0.22519245743751526, 'class': 'Ball', 'class_id': 0, 'detection_id': 'ae48ee8f-4cec-4a98-950f-60ba863d628f'}]
# Detected: Ball Confidence: 0.22519245743751526
# Processed frame 53
# Frame 54 Predictions: [{'x': 818.0, 'y': 408.5, 'width': 28.0, 'height': 23.0, 'confidence': 0.7124860286712646, 'class': 'Ball', 'class_id': 0, 'detection_id': 'c467f08e-8017-4d8c-9369-b580d3266da3'}]
# Detected: Ball Confidence: 0.7124860286712646
# Processed frame 54
# Frame 55 Predictions: [{'x': 842.0, 'y': 409.0, 'width': 28.0, 'height': 20.0, 'confidence': 0.8409964442253113, 'class': 'Ball', 'class_id': 0, 'detection_id': 'fbdde3ca-4a5c-4db1-a14b-ef0bd0ed493f'}, {'x': 214.0, 'y': 521.0, 'width': 22.0, 'height': 18.0, 'confidence': 0.23211492598056793, 'class': 'Ball', 'class_id': 0, 'detection_id': 'f80ef538-350c-47c8-adc4-69abea93c8b1'}]
# Detected: Ball Confidence: 0.8409964442253113
# Processed frame 55
# Frame 56 Predictions: [{'x': 859.0, 'y': 409.5, 'width': 22.0, 'height': 21.0, 'confidence': 0.3367478549480438, 'class': 'Ball', 'class_id': 0, 'detection_id': '7ae217c7-c70e-48bf-8e25-39dec1105ab5'}]
# Detected: Ball Confidence: 0.3367478549480438
# Processed frame 56
# Frame 57 Predictions: [{'x': 873.0, 'y': 410.0, 'width': 28.0, 'height': 24.0, 'confidence': 0.852764904499054, 'class': 'Ball', 'class_id': 0, 'detection_id': '4b93ef8f-2c8b-4579-bfe8-3c1527082c9d'}]
# Detected: Ball Confidence: 0.852764904499054
# Processed frame 57
# Frame 58 Predictions: [{'x': 884.5, 'y': 415.0, 'width': 25.0, 'height': 22.0, 'confidence': 0.4883602559566498, 'class': 'Ball', 'class_id': 0, 'detection_id': 'a965b480-a109-4fd4-bba9-786045a5e778'}]
# Detected: Ball Confidence: 0.4883602559566498
# Processed frame 58
# Frame 59 Predictions: [{'x': 889.5, 'y': 417.5, 'width': 27.0, 'height': 23.0, 'confidence': 0.6047845482826233, 'class': 'Ball', 'class_id': 0, 'detection_id': '81035998-da98-4b3f-a193-154f0b4552ef'}]
# Detected: Ball Confidence: 0.6047845482826233
# Processed frame 59
# Frame 60 Predictions: [{'x': 893.0, 'y': 420.5, 'width': 36.0, 'height': 25.0, 'confidence': 0.8792086839675903, 'class': 'Ball', 'class_id': 0, 'detection_id': '4e67498d-a33c-4397-a32e-adba1309dbd8'}]
# Detected: Ball Confidence: 0.8792086839675903
# Processed frame 60
# Frame 61 Predictions: [{'x': 892.5, 'y': 424.5, 'width': 35.0, 'height': 23.0, 'confidence': 0.8730913400650024, 'class': 'Ball', 'class_id': 0, 'detection_id': '3e1595fe-3f69-4b2e-964d-cb03cd8bb27b'}]
# Detected: Ball Confidence: 0.8730913400650024
# Processed frame 61
# Frame 62 Predictions: [{'x': 889.0, 'y': 429.0, 'width': 32.0, 'height': 22.0, 'confidence': 0.8449043035507202, 'class': 'Ball', 'class_id': 0, 'detection_id': '3890780b-7aca-4430-a039-dc0e66e7b4bb'}]
# Detected: Ball Confidence: 0.8449043035507202
# Processed frame 62
# Frame 63 Predictions: []
# Processed frame 63
# Frame 64 Predictions: [{'x': 875.5, 'y': 440.5, 'width': 29.0, 'height': 23.0, 'confidence': 0.27148789167404175, 'class': 'Ball', 'class_id': 0, 'detection_id': '86e56895-03eb-467a-8163-62393affc8d6'}]
# Detected: Ball Confidence: 0.27148789167404175
# Processed frame 64
# Frame 65 Predictions: [{'x': 870.0, 'y': 445.5, 'width': 28.0, 'height': 25.0, 'confidence': 0.8467230796813965, 'class': 'Ball', 'class_id': 0, 'detection_id': '0a653698-d619-46c9-8133-fea520b04d11'}]
# Detected: Ball Confidence: 0.8467230796813965
# Processed frame 65
# Frame 66 Predictions: [{'x': 862.0, 'y': 449.0, 'width': 30.0, 'height': 24.0, 'confidence': 0.8385863304138184, 'class': 'Ball', 'class_id': 0, 'detection_id': '696a9f11-ca4a-4d05-88f8-c612aa62e72a'}]
# Detected: Ball Confidence: 0.8385863304138184
# Processed frame 66
# Frame 67 Predictions: [{'x': 858.5, 'y': 455.5, 'width': 33.0, 'height': 23.0, 'confidence': 0.8695354461669922, 'class': 'Ball', 'class_id': 0, 'detection_id': '5260979c-ecaa-4be4-833b-278aeb982450'}]
# Detected: Ball Confidence: 0.8695354461669922
# Processed frame 67
# Frame 68 Predictions: [{'x': 855.5, 'y': 462.5, 'width': 29.0, 'height': 23.0, 'confidence': 0.8424120545387268, 'class': 'Ball', 'class_id': 0, 'detection_id': '85ac9cac-d711-47fa-a9e8-5fddca1ff456'}]
# Detected: Ball Confidence: 0.8424120545387268
# Processed frame 68
# Frame 69 Predictions: []
# Processed frame 69
# Frame 70 Predictions: []
# Processed frame 70
# Frame 71 Predictions: [{'x': 866.5, 'y': 483.0, 'width': 29.0, 'height': 22.0, 'confidence': 0.7607636451721191, 'class': 'Ball', 'class_id': 0, 'detection_id': '8ee1d3d9-8035-45cc-a8a2-770c5adb77f2'}]
# Detected: Ball Confidence: 0.7607636451721191
# Processed frame 71
# Frame 72 Predictions: [{'x': 878.5, 'y': 489.5, 'width': 31.0, 'height': 23.0, 'confidence': 0.7490463256835938, 'class': 'Ball', 'class_id': 0, 'detection_id': 'a42ae37b-693f-4811-8aa6-24e6121ce421'}]
# Detected: Ball Confidence: 0.7490463256835938
# Processed frame 72
# Frame 73 Predictions: [{'x': 887.5, 'y': 499.5, 'width': 35.0, 'height': 27.0, 'confidence': 0.88116055727005, 'class': 'Ball', 'class_id': 0, 'detection_id': '8724de12-9f84-473b-874e-5096c9fb75d7'}]
# Detected: Ball Confidence: 0.88116055727005
# Processed frame 73
# Frame 74 Predictions: [{'x': 908.5, 'y': 512.5, 'width': 35.0, 'height': 27.0, 'confidence': 0.8898950219154358, 'class': 'Ball', 'class_id': 0, 'detection_id': '075d881d-310c-49ba-a47a-355d3208f076'}]
# Detected: Ball Confidence: 0.8898950219154358
# Processed frame 74
# Frame 75 Predictions: [{'x': 931.5, 'y': 526.5, 'width': 29.0, 'height': 25.0, 'confidence': 0.6692603826522827, 'class': 'Ball', 'class_id': 0, 'detection_id': '3ed99a8c-4220-4d8d-8400-23cc6721a7ce'}, {'x': 1440.5, 'y': 370.0, 'width': 43.0, 'height': 30.0, 'confidence': 0.421411395072937, 'class': 'Ball', 'class_id': 0, 'detection_id': 'c83e758f-7021-41dc-81a3-b49e06c5a671'}]
# Detected: Ball Confidence: 0.6692603826522827
# Processed frame 75
# Frame 76 Predictions: [{'x': 953.5, 'y': 540.5, 'width': 25.0, 'height': 23.0, 'confidence': 0.7444392442703247, 'class': 'Ball', 'class_id': 0, 'detection_id': 'abdf411d-efef-47ab-a78d-67d3ad27d480'}]
# Detected: Ball Confidence: 0.7444392442703247
# Processed frame 76
# Frame 77 Predictions: [{'x': 982.5, 'y': 555.5, 'width': 31.0, 'height': 25.0, 'confidence': 0.7561529278755188, 'class': 'Ball', 'class_id': 0, 'detection_id': 'cba65680-63a6-4c00-9243-8a70bb85a781'}]
# Detected: Ball Confidence: 0.7561529278755188
# Processed frame 77
# Frame 78 Predictions: []
# Processed frame 78
# Frame 79 Predictions: []
# Processed frame 79
# Frame 80 Predictions: [{'x': 1478.0, 'y': 404.0, 'width': 20.0, 'height': 22.0, 'confidence': 0.7084214687347412, 'class': 'Ball', 'class_id': 0, 'detection_id': '2d60912a-3d99-44d5-b826-8ba339feed71'}]
# Detected: Ball Confidence: 0.7084214687347412
# Processed frame 80
# Frame 81 Predictions: [{'x': 1459.5, 'y': 399.5, 'width': 21.0, 'height': 23.0, 'confidence': 0.35950806736946106, 'class': 'Ball', 'class_id': 0, 'detection_id': 'b2d77543-79c0-4a0e-991d-2d9449af38cb'}]
# Detected: Ball Confidence: 0.35950806736946106
# Processed frame 81
# Frame 82 Predictions: []
# Processed frame 82
# Frame 83 Predictions: []
# Processed frame 83
# Frame 84 Predictions: []
# Processed frame 84
# Frame 85 Predictions: []
# Processed frame 85
# Frame 86 Predictions: []
# Processed frame 86
# Frame 87 Predictions: [{'x': 934.5, 'y': 454.5, 'width': 55.0, 'height': 49.0, 'confidence': 0.24203886091709137, 'class': 'Ball', 'class_id': 0, 'detection_id': 'f4d53070-3421-4a48-a189-3214da0ae73b'}]
# Detected: Ball Confidence: 0.24203886091709137
# Processed frame 87
# Frame 88 Predictions: [{'x': 847.5, 'y': 585.5, 'width': 27.0, 'height': 25.0, 'confidence': 0.26531118154525757, 'class': 'Ball', 'class_id': 0, 'detection_id': 'dc6c62eb-2699-41f3-90b3-77319f7b031d'}]
# Detected: Ball Confidence: 0.26531118154525757
# Processed frame 88
# Frame 89 Predictions: []
# Processed frame 89
# Frame 90 Predictions: []
# Processed frame 90
# Frame 91 Predictions: []
# Processed frame 91
# Frame 92 Predictions: []
# Processed frame 92
# Frame 93 Predictions: []
# Processed frame 93
# Frame 94 Predictions: []
# Processed frame 94
# Frame 95 Predictions: []
# Processed frame 95
# Frame 96 Predictions: []
# Processed frame 96
# Frame 97 Predictions: []
# Processed frame 97
# Frame 98 Predictions: []
# Processed frame 98
# Frame 99 Predictions: [{'x': 836.0, 'y': 623.5, 'width': 22.0, 'height': 21.0, 'confidence': 0.375529944896698, 'class': 'Ball', 'class_id': 0, 'detection_id': '655336d6-6736-4212-a88e-42a403c6ae4c'}]
# Detected: Ball Confidence: 0.375529944896698
# Processed frame 99
# Frame 100 Predictions: []
# Processed frame 100
# Frame 101 Predictions: [{'x': 831.0, 'y': 673.5, 'width': 32.0, 'height': 25.0, 'confidence': 0.5873651504516602, 'class': 'Ball', 'class_id': 0, 'detection_id': '49b1a6b2-eddc-4541-a706-7ff8d4d8e436'}]
# Detected: Ball Confidence: 0.5873651504516602
# Processed frame 101
# Frame 102 Predictions: [{'x': 829.0, 'y': 659.5, 'width': 26.0, 'height': 23.0, 'confidence': 0.7643694877624512, 'class': 'Ball', 'class_id': 0, 'detection_id': '24f1ca9e-95c5-43ef-8e2e-2c786241e9bf'}]
# Detected: Ball Confidence: 0.7643694877624512
# Processed frame 102
# Frame 103 Predictions: []
# Processed frame 103
# Frame 104 Predictions: []
# Processed frame 104
# Frame 105 Predictions: []
# Processed frame 105
# Frame 106 Predictions: []
# Processed frame 106
# Frame 107 Predictions: []
# Processed frame 107
# Frame 108 Predictions: []
# Processed frame 108
# Frame 109 Predictions: [{'x': 819.5, 'y': 237.5, 'width': 29.0, 'height': 27.0, 'confidence': 0.28057295083999634, 'class': 'Ball', 'class_id': 0, 'detection_id': '85105d3d-ec3c-4c8d-b149-12fd73c2d20e'}]
# Detected: Ball Confidence: 0.28057295083999634
# Processed frame 109
# Frame 110 Predictions: []
# Processed frame 110
# Frame 111 Predictions: []
# Processed frame 111
# Frame 112 Predictions: []
# Processed frame 112
# Frame 113 Predictions: []
# Processed frame 113
# Frame 114 Predictions: []
# Processed frame 114
# Frame 115 Predictions: []
# Processed frame 115
# Frame 116 Predictions: []
# Processed frame 116
# Frame 117 Predictions: [{'x': 773.0, 'y': 563.5, 'width': 32.0, 'height': 27.0, 'confidence': 0.22092820703983307, 'class': 'Ball', 'class_id': 0, 'detection_id': '1be91535-864d-412c-9d3b-89cbf8e293db'}]
# Detected: Ball Confidence: 0.22092820703983307
# Processed frame 117
# Frame 118 Predictions: []
# Processed frame 118
# Frame 119 Predictions: []
# Processed frame 119
# Frame 120 Predictions: []
# Processed frame 120
# Frame 121 Predictions: []
# Processed frame 121
# Frame 122 Predictions: []
# Processed frame 122
# Frame 123 Predictions: [{'x': 1687.5, 'y': 70.5, 'width': 31.0, 'height': 25.0, 'confidence': 0.4497522711753845, 'class': 'Ball', 'class_id': 0, 'detection_id': 'd159eeab-893c-4437-9db7-1cd1b8fc0fed'}]
# Detected: Ball Confidence: 0.4497522711753845
# Processed frame 123
# Frame 124 Predictions: []
# Processed frame 124
# Frame 125 Predictions: []
# Processed frame 125
# Frame 126 Predictions: [{'x': 1713.0, 'y': 54.5, 'width': 28.0, 'height': 23.0, 'confidence': 0.3071458637714386, 'class': 'Ball', 'class_id': 0, 'detection_id': 'df899f2b-2f23-42f4-840a-4e470e619639'}]
# Detected: Ball Confidence: 0.3071458637714386
# Processed frame 126
# Frame 127 Predictions: []
# Processed frame 127
# Frame 128 Predictions: []
# Processed frame 128
# Frame 129 Predictions: []
# Processed frame 129
# Frame 130 Predictions: []
# Processed frame 130
# Frame 131 Predictions: []
# Processed frame 131
# Frame 132 Predictions: [{'x': 847.0, 'y': 602.0, 'width': 32.0, 'height': 30.0, 'confidence': 0.3917511999607086, 'class': 'Ball', 'class_id': 0, 'detection_id': 'df882824-d050-42b7-aaed-a32ebd13311b'}]
# Detected: Ball Confidence: 0.3917511999607086
# Processed frame 132
# Frame 133 Predictions: []
# Processed frame 133
# Frame 134 Predictions: []
# Processed frame 134
# Frame 135 Predictions: []
# Processed frame 135
# Frame 136 Predictions: []
# Processed frame 136
# Frame 137 Predictions: []
# Processed frame 137
# Frame 138 Predictions: []
# Processed frame 138
# Frame 139 Predictions: []
# Processed frame 139
# Frame 140 Predictions: []
# Processed frame 140
# Frame 141 Predictions: [{'x': 774.0, 'y': 609.5, 'width': 36.0, 'height': 35.0, 'confidence': 0.5247437953948975, 'class': 'Ball', 'class_id': 0, 'detection_id': 'a5d0a882-17ae-4995-a54f-d4b2eaab7f1f'}]
# Detected: Ball Confidence: 0.5247437953948975
# Processed frame 141
# Frame 142 Predictions: [{'x': 768.0, 'y': 606.5, 'width': 38.0, 'height': 39.0, 'confidence': 0.5473697185516357, 'class': 'Ball', 'class_id': 0, 'detection_id': 'e87c662f-ecdb-441a-89c6-87c2a8de0d47'}]
# Detected: Ball Confidence: 0.5473697185516357
# Processed frame 142
# Frame 143 Predictions: [{'x': 773.5, 'y': 608.5, 'width': 43.0, 'height': 43.0, 'confidence': 0.299862265586853, 'class': 'Ball', 'class_id': 0, 'detection_id': '8a33e4f1-afd0-4725-8dfc-df31d554b20e'}]
# Detected: Ball Confidence: 0.299862265586853
# Processed frame 143
# Frame 144 Predictions: []
# Processed frame 144
# Frame 145 Predictions: []
# Processed frame 145
# Frame 146 Predictions: []
# Processed frame 146
# Frame 147 Predictions: []
# Processed frame 147
# Frame 148 Predictions: []
# Processed frame 148
# Frame 149 Predictions: []
# Processed frame 149
# Frame 150 Predictions: []
# Processed frame 150
# Frame 151 Predictions: []
# Processed frame 151
# Frame 152 Predictions: []
# Processed frame 152
# Frame 153 Predictions: []
# Processed frame 153
# Frame 154 Predictions: []
# Processed frame 154
# Frame 155 Predictions: []
# Processed frame 155
# Frame 156 Predictions: []
# Processed frame 156
# Frame 157 Predictions: []
# Processed frame 157
# Frame 158 Predictions: []
# Processed frame 158
# Frame 159 Predictions: []
# Processed frame 159
# Frame 160 Predictions: []
# Processed frame 160
# Frame 161 Predictions: []
# Processed frame 161
# Frame 162 Predictions: []
# Processed frame 162
# Frame 163 Predictions: []
# Processed frame 163
# Frame 164 Predictions: []
# Processed frame 164
# Frame 165 Predictions: []
# Processed frame 165
# Frame 166 Predictions: []
# Processed frame 166
# Frame 167 Predictions: [{'x': 630.0, 'y': 499.5, 'width': 40.0, 'height': 35.0, 'confidence': 0.20075851678848267, 'class': 'Ball', 'class_id': 0, 'detection_id': '74e62783-abcd-4c15-90ae-c9c48cd863e1'}]
# Detected: Ball Confidence: 0.20075851678848267
# Processed frame 167
# Frame 168 Predictions: []
# Processed frame 168
# Frame 169 Predictions: []
# Processed frame 169
# Frame 170 Predictions: [{'x': 630.0, 'y': 496.0, 'width': 54.0, 'height': 38.0, 'confidence': 0.8770411014556885, 'class': 'Ball', 'class_id': 0, 'detection_id': '9a35017c-9a70-4d23-a35c-9f498273e9be'}]
# Detected: Ball Confidence: 0.8770411014556885
# Processed frame 170
# Frame 171 Predictions: [{'x': 627.5, 'y': 496.0, 'width': 51.0, 'height': 36.0, 'confidence': 0.8742267489433289, 'class': 'Ball', 'class_id': 0, 'detection_id': '047e475e-b596-41b5-8411-cd9466deb8be'}]
# Detected: Ball Confidence: 0.8742267489433289
# Processed frame 171
# Frame 172 Predictions: [{'x': 619.0, 'y': 496.0, 'width': 50.0, 'height': 32.0, 'confidence': 0.2928254008293152, 'class': 'Ball', 'class_id': 0, 'detection_id': 'e9682aae-547b-40f0-81aa-54bd9696aa9d'}]
# Detected: Ball Confidence: 0.2928254008293152
# Processed frame 172
# Frame 173 Predictions: []
# Processed frame 173
# Frame 174 Predictions: [{'x': 606.0, 'y': 499.0, 'width': 42.0, 'height': 32.0, 'confidence': 0.36099299788475037, 'class': 'Ball', 'class_id': 0, 'detection_id': 'c06dd059-e1c3-4f3c-aeb8-5726e9601d30'}]
# Detected: Ball Confidence: 0.36099299788475037
# Processed frame 174
# Frame 175 Predictions: []
# Processed frame 175
# Frame 176 Predictions: [{'x': 603.5, 'y': 496.0, 'width': 47.0, 'height': 32.0, 'confidence': 0.4133685529232025, 'class': 'Ball', 'class_id': 0, 'detection_id': '443809bd-84f1-450c-95b9-5446c7c5eeb1'}, {'x': 983.0, 'y': 401.0, 'width': 34.0, 'height': 42.0, 'confidence': 0.34945717453956604, 'class': 'Ball', 'class_id': 0, 'detection_id': 'd92da2db-376b-423d-b0a3-03e45cdc29f0'}]
# Detected: Ball Confidence: 0.4133685529232025
# Processed frame 176
# Frame 177 Predictions: [{'x': 605.0, 'y': 491.5, 'width': 46.0, 'height': 29.0, 'confidence': 0.3158469498157501, 'class': 'Ball', 'class_id': 0, 'detection_id': 'c1eb5087-e94f-4efb-aed4-4344c135c710'}]
# Detected: Ball Confidence: 0.3158469498157501
# Processed frame 177
# ✅ Video saved: smoothed_tracking.mp4
